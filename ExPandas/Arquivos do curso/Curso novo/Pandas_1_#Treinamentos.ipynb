# %% [markdown]
# ### PASSO 1: Importando as bibliotecas!
#    *- Numpy será importado também pois quase sempre é ultilizado junto com pandas.*
#
#    *-Pandas É construído sobre numpy. Muitas operações internas usam numpy diretamente.*

# %%
import pandas as pd
import numpy as np
#podemos ver a versão da bibliote printando __version__ da biblioteca

# %% [markdown]
# ### PASSO 2: Importando as bases!
#    *- Primeiro transformamos elas em dfs:*
#
#          Alguns parâmetros:
#             - ENCODING: Problemas com caracteres especiais ('latin1' ou 'utf-8')
#             - SEP: Escolher o separador
#             - LOW MEMORY = FALSE: Nao economizar memoria com colunas contendo dados que ele nao reconheca um tipo só, ou seja, numeros e textos
#    *- Depois podemos enxergálas com o comando display* **APENAS EM ARQUIVOS .IPYNB**
# >
# >    lembrando: DataFrame = 2 dimensões
# >
# > Series = 1 dimensão
# >
# > Para mais dimensões → ndarray (numpy)

# %%
df_vendas = pd.read_csv(r"BASES\vendas_tech.csv",low_memory = False) #CHAMAR OS DATAFRAMES DE DFS
display(df_vendas) #APENAS EM ARQUIVOS.IPYNB, USANDO PRINT FORA DESSES CASOS
df_gerentes = pd.read_excel(r"BASES\gerentes_lojas.xlsx")
display(df_gerentes) #APENAS EM ARQUIVOS.IPYNB, USANDO PRINT FORA DESSES CASOS

# %% [markdown]
# ### PASSO 3: Inspecionando e visualizando os dataframes!
#
#    - Display():
#
#          -Mostra de forma bonita as primeiras e ultimas 5 linhas do df
#    - Display(Df.head())
#
#          -Mostra as primeiras linhas apenas podendo receber o parametro em INT para a quantidade de linhas impressas
#
#    - Display(Df.tail())
#
#          -Mostra as últimas linhas apenas podendo receber o parametro em INT para a quantidade de linhas impressas
#    - Display(Df.sample())
#
#          -Mostra linhas aleatórias podendo receber o parametro em INT para a quantidade de linhas impressas
#    - Display(Df.shape)
#
#          -Mostra uma tupla com o tamanho do df em linhas e colunas
#    - Display(Df.columns)
#
#          -Retorna uma lista com o nome de todas as colunas
#
#    - Display(Df.info())
#
#          -Mostra algumas informações como tipo de dados das colunas afim de corrigir erros e verificar colunas com dados vazios
#    - Display(Df.describe())
#
#          -Mostra algumas informações estatísticas das coluns numéricas presentes na base de dados
#          PARAMETRO: include='all' tambem traz colunas textuais
#
#    - Display(df.isna())
#       -Mostra um df com mascara de falso e verdadeiropara valores nulos
#       -.sum() pode ser usado para mostrar uma tabela de soma de nulos por coluna
#
#    - Display(df.select_dtypes)
#       -Seleciona colunas com o tipo incluido
#       -PARAMETRO: include para incluir o que quiser, exemplo: (include='number1)

# %%
display(df_vendas)
display(df_vendas.head(10))
display(df_vendas.tail(5))
display(df_vendas.shape)
display(df_vendas.info())
display(df_vendas.columns)
display(df_vendas.describe())
display(df_vendas.describe(include='all'))
