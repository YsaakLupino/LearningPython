# %% [markdown]
# # 🧠 BLOCO 1 — Importação
#
# ### Programação
#
# 1. Importe pandas como pd
# 2. Importe numpy como np
# 3. Imprima versão do pandas
# 4. Crie DataFrame 3x5
# 5. Crie array numpy e converta em DataFrame
#
# ### Dissertativas
#
# 6. Por que usamos pd?
# 7. Qual papel do numpy?
# 8. O que é DataFrame?
#
# ### Verdadeiro/Falso
#
# 9. Pandas depende do numpy
# 10. DataFrame é bidimensional
# 11. Numpy serve só pra gráficos
#
# ---

# %%
# 1. Importe pandas como pd
import pandas as pd
# 2. Importe numpy como np
import numpy as np
# 3. Imprima versão do pandas
print(pd.__version__)
# 4. Crie DataFrame 3x5
display(pd.DataFrame({1:[1,2,3],2:[1,2,3],3:[1,2,3],4:[1,2,3],5:[1,2,3]}))
# 5. Crie array numpy e converta em DataFrame
array_ = np.array((1,2,3,4))
display(pd.DataFrame(array_))
# 6. Por que usamos pd?
'''Para abreviar pandas e a programação ficar mais fácil'''
# 7. Qual papel do numpy?
'''Ao ultilizar pandas muitas funções ele usa o numpy entoa é bom importar 
   ao usar o pandasalem disso ele tem algumas coisas de visuaçização bacana 
   em graficos'''
# 8. O que é DataFrame?
'''é o nome da classe em pandas que trata os dados como tabelas, basicamente'''
# 9. Pandas depende do numpy
'''nao, mas funcionam muito bem juntos, algumas funções usam coisa nativas do numpy sim, mas não todas'''
'''INCORRETO: Pandas É construído sobre numpy. Muitas operações internas usam numpy diretamente.'''
# 10. DataFrame é bidimensional
'''Sim, acho que talvez ate seja possivel criar com mais dimensões.. Mas a principio sim'''
'''MEIACERTA: DataFrame = 2 dimensões

Series = 1 dimensão

Para mais dimensões → ndarray (numpy)'''
# 11. Numpy serve só pra gráficos
'''Não.. Ele tambem tem funções matematicas'''

# %% [markdown]
# # 📂 BLOCO 2 — Leitura
#
# ### Programação
#
# 12. Leia dados.csv
# 13. Leia CSV com ;
# 14. Leia CSV latin1
# 15. Leia clientes.xlsx
# 16. Leia CSV com low_memory=False
# 17. Crie df_vendas e df_gerentes
# 18. Mostre primeiras linhas
#
# ### Complete
#
# 19. df = pd.________("arquivo.csv")
# 20. low_memory = ___
#
# ### Dissertativas
#
# 21. Para que serve low_memory?
# 22. O que é encoding?
# 23. Quando usar sep?
# 24. Diferença CSV vs Excel
#
# ### Múltipla escolha
#
# 25. Qual lê Excel?
# 26. Encoding serve para quê?

# %%
# 12. Leia dados.csv
pd.read_csv(r'BASES\vendas_tech.csv')
# 13. Leia CSV com ;  
pd.read_csv(r'BASES\vendas_tech.csv',sep=';')
# 14. Leia CSV latin1  
pd.read_csv(r'BASES\vendas_tech.csv', encoding='latin1')
# 15. Leia clientes.xlsx
'''pd.read_csv('clientes.xlsx')
INCORRETO: pd.read_excel('clientes.xlsx')'''
# 16. Leia CSV com low_memory=False  
df_csv = pd.read_csv(r'BASES\vendas_tech.csv', low_memory=False)
# 18. Mostre primeiras linhas
display(df_csv.head(12))
# 19. df = pd.________("arquivo.csv")
'''df = pd.read_csv("arquivo.csv")'''
# 20. low_memory = ___  
'''False'''
# # 21. Para que serve low_memory?  
'''Para que o carregamento da planilhe deixe de usar pouco memoria para reconhecer os dados como texto e nao achar que sao varios tipos de dados'''
# # 22. O que é encoding?
'''Tipo de decodificação dos caracteres para evitar bugs com acentos e pontuações'''
# # 23. Quando usar sep?  
'''Sep é para escolher qual separador sera usando na leitura do arquivo'''
# # 24. Diferença CSV vs Excel  
'''Excel é uma planilha do exel, geralmente o formato é xlsx, CVS é comma
separated vallues que é um arquivo que representa uma tabela tambem mas 
com dados separados por virgulas'''
# 25. Qual lê Excel?
'''pd.read_excel()'''
# 26. Encoding serve para quê? ;
'''para decodificação dos caracteres ao carregar arquivo para evitar bugs com acentos e pontuações'''

# %% [markdown]
# # 👀 BLOCO 3 — Inspeção
#
# 27. head(10)
# 28. tail(3)
# 29. sample(7)
# 30. shape
# 31. columns
# 32. info()
# 33. describe()
#
# ### Interpretação
#
# 34. df.shape
# 35. df.info()
# 36. Diferença head/tail
#
# ### Dissertativas
#
# 37. Para que serve describe
# 38. Quando usar sample
# 39. Utilidade columns
# 40. Por que rodar info primeiro
#
# ### Verdadeiro/Falso
#
# 41. shape retorna linhas/colunas
# 42. columns mostra tipos
# 43. describe só números
# 44. display é do Jupyter

# %%
# 27. head(10)  
'''Retorna primeiras 10 linhas'''
# 28. tail(3) 
'''Retorna ultimas 3 linhas''' 
# 29. sample(7)  
'''Me tras 7 linhas aleatorias'''
# 30. shape  
'''Propriedade da classe df que contem numero de linhas e colunas do df'''
# 31. columns  
'''propriedade com as Colunas do df'''
# 32. info()  
'''Traz informações como tipo de dados tabela, quantas linhas tem e quantos valor NAN'''
# 33. describe()
'''Descrição mais estatística do df'''
# 34. df.shape
'''Traz propriedade de shape do df ( tupla numero de linhas e colunas)'''
# 35. df.info()
'''Tras informações sobre o df a respeito dos dados nas colunas, tipo e nulificados '''
# 36. Diferença head/tail   
'''head tras x primeiras linhas e tail tras x ultimas linhas'''
# 37. Para que serve describe  
'''traz leve analise estatistica do df, como contagem, media 25% 75% etc'''
# 38. Quando usar sample
'''Para indentificar inconsitencias no dados para assim fazer uma boa transformação no processo ETL'''
# 39. Utilidade columns
'''propriedade que guarda array com nome das colunas do df'''
# 40. Por que rodar info primeiro
'''é a função que traz a exploração inicial, um ponto de partida'''
# 41. shape retorna linhas/colunas 
'''VERDADEIRO''' 
# 42. columns mostra tipos
'''FALSO'''  
# 43. describe só números 
'''VERDADEIRO''' 
'''INCORRETO: Atualmente o parâmetro (include='all') traz texto tambem'''
# 44. display é do Jupyter 
'''VERDADEIRO'''

# %% [markdown]
# # 🔍 BLOCO 4 — Estrutura
#
# 45. Pipeline completo (read → head → info → describe)
# 46. Extraia linhas
# 47. Extraia colunas
#
# ### Complete
#
# 48. df.shape[__]
# 49. df.shape[__]
#
# ---
#
# # 🧪 BLOCO 5 — Mini Projetos
#
# 50. CSV vendas (head/info/describe/columns)
# 51. Excel funcionários (colunas/nulos/números)
#
# ---

# %%
# 45. Pipeline completo (read → head → info → describe)
df_csv = pd.read_csv(r'BASES\vendas_tech.csv')
display(df_csv.head(10))
display(df_csv.info())
display(df_csv.describe)
'''INCORRETO FALTOU () DEPOIS DO DESCRIBE'''
# 46. Extraia linhas
print('Quantidade de linhas: ', df_csv.shape[0]) 
# # 47. Extraia colunas
print('Quantidade de colunas: ', df_csv.shape[1]) 
# 48. df.shape[__]
'''0 para linhas--------------'''
# 49. df.shape[__]            |> isso pq shape retorna uma tupla assim: (Linhas,Colunas)
'''1 para colunas-------------'''      
# 50. CSV vendas (head/info/describe/columns) 
display(df_csv.head(10))
display(df_csv.info())
display(df_csv.describe())
print(df_csv.columns)
# 51. Excel funcionários (colunas/nulos/números)  
display(df_csv.columns)
display(df_csv.isna().sum())
display(df_csv.select_dtypes(include='number'))

# %% [markdown]
# # 🔁 BLOCO 6 — Repetição
#
# 52. read_csv
# 53. head
# 54. info
# 55. describe
# 56. columns
# 57. shape
#
# Repita com XLSX:
#
# 58
# 59
# 60
# 61
# 62
# 63
# 64
# 65

# %%
# 52. read_csv
df_novo_csv = pd.read_csv(r'BASES\vendas_tech.csv')
# 53. head 
display(df_novo_csv.head(7)) 
# 54. info
display(df_novo_csv.info())
# 55. describe
display(df_novo_csv.describe())
# 56. columns
display(df_novo_csv.columns)
# 57. shape
display(df_novo_csv.shape)
# 58. read_xlsx
df_novo_xlsx = pd.read_excel(r'BASES\gerentes_lojas.xlsx')
# 59. head
display(df_novo_xlsx.head(3))
# 60. info
display(df_novo_xlsx.info())
# 61. describe
display(df_novo_xlsx.describe())
# 62. columns
display(df_novo_xlsx.columns)
# 63. shape
display(df_novo_xlsx.shape)

# %% [markdown]
# # ⚠ BLOCO 7 — Conceitos
#
# 66. O que é ETL
# 67. Por que inspecionar dados
# 68. Dado bruto vs tratado
# 69. Tipos errados quebram análises?
#
# ### Programação
#
# 70. Crie DataFrame manual
# 71. Salve em CSV
# 72. Recarregue CSV

# %%
# 66. O que é ETL
'''Processo extract transform and load, que garante que os dados sejam retirados de um lugar
 e cheguem em outro para ser analisado após uma limpeza'''
# 67. Por que inspecionar dados  
'''Para notar que tipo de transformações serao necessarias'''
# 68. Dado bruto vs tratado 
'''Antes de transformar e depois de passar por ajusta nos tipos de dados e exclusao de dados nulos e coisas assim'''
# 69. Tipos errados quebram análises? 
'''Sim pois se caso houver dados de string junto com dados numeriocos possiveis contas por exemplo gerariam erros'''
# 70. Crie DataFrame manual
'''Ele tem que vir de algum lugar, eu escolho um dicionario'''
dictio = {'Coluna1':['Linha A','Linha B','Linha C'], 'Coluna2': ['Linha A','Linha B','Linha C'],'Coluna3':['Linha A','Linha B','Linha C']}
display(pd.DataFrame(dictio))
